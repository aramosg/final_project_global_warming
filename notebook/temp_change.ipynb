# %%
#Dependencies #Lau
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing file
temp_chng = 'GitHub_Lau/Resources/FAOSTAT_data_en_8-13-2022.csv'
temp_chng_df = pd.read_csv(temp_chng)

# %%
temp_chng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15067 entries, 0 to 15066
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       15067 non-null  object
#  1   Domain            15067 non-null  object
#  2   Area Code (FAO)   15067 non-null  int64
#  3   Area              15067 non-null  object
#  4   Element Code      15067 non-null  int64
#  5   Element           15067 non-null  object
#  6   Months Code       15067 non-null  int64
#  7   Months            15067 non-null  object
#  8   Year Code         15067 non-null  int64
#  9   Year              15067 non-null  int64
#  10  Unit              13764 non-null  object
#  11  Value             13248 non-null  float64
#  12  Flag              13764 non-null  object
#  13  Flag Description  13764 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.6+ MB

# %%
temp_chng_df.head()
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change                2  Afghanistan          7271
# 4          ET  Temperature change                2  Afghanistan          7271
#
#               Element  Months Code               Months  Year Code  Year Unit  \
# 0  Temperature change         7020  Meteorological year       1961  1961   °C
# 1  Temperature change         7020  Meteorological year       1962  1962   °C
# 2  Temperature change         7020  Meteorological year       1963  1963   °C
# 3  Temperature change         7020  Meteorological year       1964  1964   °C
# 4  Temperature change         7020  Meteorological year       1965  1965   °C
#
#    Value Flag Flag Description
# 0 -0.105   Fc  Calculated data
# 1 -0.157   Fc  Calculated data
# 2  0.852   Fc  Calculated data
# 3 -0.743   Fc  Calculated data
# 4 -0.211   Fc  Calculated data

# %%
# Checking Columns to drop
col_drop = temp_chng_df[['Domain Code','Domain', 'Element Code', 'Element', 'Months Code', 'Months']].drop_duplicates()
col_drop.to_dict('records')
# Out:
# [{'Domain Code': 'ET',
#   'Domain': 'Temperature change',
#   'Element Code': 7271,
#   'Element': 'Temperature change',
#   'Months Code': 7020,
#   'Months': 'Meteorological year'}]

# %%
# Difference between Flags
flag_f_desc = temp_chng_df[['Flag', 'Flag Description']].drop_duplicates()
flag_f_desc.to_dict('records')
# Out:
# [{'Flag': 'Fc', 'Flag Description': 'Calculated data'},
#  {'Flag': 'NV', 'Flag Description': 'Data not available'},
#  {'Flag': nan, 'Flag Description': nan}]

# %%
# Validating if Year Code and Year column are the same
temp_chng_df['Year Code'].equals(temp_chng_df['Year'])
# Out:
# True

# %%
# Rename columns
temp_chng_df = temp_chng_df.rename(columns= {'Value': 'Temp Change (°C)'})
#Removing unecessary columns
temp_chng_df_c = temp_chng_df.drop(['Domain Code', 'Domain', 'Element Code', 'Element', 'Months Code', 'Months', 'Year Code'], axis=1)
temp_chng_df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15067 entries, 0 to 15066
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area Code (FAO)   15067 non-null  int64
#  1   Area              15067 non-null  object
#  2   Year              15067 non-null  int64
#  3   Unit              13764 non-null  object
#  4   Temp Change (°C)  13248 non-null  float64
#  5   Flag              13764 non-null  object
#  6   Flag Description  13764 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 824.1+ KB

# %%
#Filter years from 1970 to 2020
temp_chng_df_c = temp_chng_df_c[(temp_chng_df_c['Year']>= 1970) & (temp_chng_df_c['Year']<= 2020)]
temp_chng_df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12597 entries, 9 to 15065
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area Code (FAO)   12597 non-null  int64
#  1   Area              12597 non-null  object
#  2   Year              12597 non-null  int64
#  3   Unit              11599 non-null  object
#  4   Temp Change (°C)  11149 non-null  float64
#  5   Flag              11599 non-null  object
#  6   Flag Description  11599 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 787.3+ KB

# %%
temp_chng_df_c.head(3)
# Out:
#     Area Code (FAO)         Area  Year Unit  Temp Change (°C) Flag  \
# 9                 2  Afghanistan  1970   °C             0.898   Fc
# 10                2  Afghanistan  1971   °C             0.652   Fc
# 11                2  Afghanistan  1972   °C            -1.089   Fc
#
#    Flag Description
# 9   Calculated data
# 10  Calculated data
# 11  Calculated data

# %%
#temp_chng_df_c.to_csv('temp_change.csv')
