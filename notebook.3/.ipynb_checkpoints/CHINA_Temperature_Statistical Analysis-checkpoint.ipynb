# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = "../Resources.2/general_dataset_v5.csv"
temp_anom_df = pd.read_csv(file_path)
temp_anom_df.head()
# Out:
#   country_code country_name  year  annual_co2_emissions_tons  \
# 0          AFG  Afghanistan  1988                    2856896
# 1          AFG  Afghanistan  1990                    2603238
# 2          AFG  Afghanistan  1991                    2427366
# 3          AFG  Afghanistan  1992                    1379462
# 4          AFG  Afghanistan  1993                    1333055
#
#    inflation_inflation_gdp_deflation  deaths_from_drought  \
# 0                                NaN                  0.0
# 1                                NaN                  0.0
# 2                                NaN                  0.0
# 3                                NaN                  0.0
# 4                                NaN                  0.0
#
#    deaths_from_extreme_temps  deaths_from_floods  deaths_from_storms  \
# 0                        0.0                 0.0                 0.0
# 1                      144.0                 0.0                 0.0
# ...

# %%
temp_anom_df= temp_anom_df[(temp_anom_df['country_code'] == 'CHN')]
temp_anom_df.head()
# Out:
#     country_code country_name  year  annual_co2_emissions_tons  \
# 530          CHN        China  1988                 2425893553
# 531          CHN        China  1989                 2463654367
# 532          CHN        China  1990                 2484854820
# 533          CHN        China  1991                 2606096182
# 534          CHN        China  1992                 2730787587
#
#      inflation_inflation_gdp_deflation  deaths_from_drought  \
# 530                          12.107661               1400.0
# 531                           8.602465                  0.0
# 532                           5.711224                  0.0
# 533                           6.714537               2000.0
# 534                           8.190323                  0.0
#
#      deaths_from_extreme_temps  deaths_from_floods  deaths_from_storms  \
# 530                        0.0              1243.0               335.0
# 531                        0.0              2000.0              1115.0
# ...

# %%
temp_anom_df= temp_anom_df.drop(['country_code','inflation_inflation_gdp_deflation',
 'deaths_from_drought',
 'deaths_from_extreme_temps',
 'deaths_from_floods',
 'deaths_from_storms',
 'deaths_from_wildfires',
 'people_affected_by_drought_per_100k',
 'people_affected_by_extreme_temperatures_per_100k',
 'people_affected_by_floods_per_100k',
 'people_affected_by_storms_per_100k',
 'people_affected_by_wildfires_per_100k',
 'economic_damages_from_drought',
 'economic_damages_from_drought_as_a_share_of_gdp',
 'economic_damages_from_extreme_temperatures',
 'economic_damages_from_extreme_temperatures_as_a_share_of_gdp',
 'economic_damages_from_floods',
 'economic_damages_from_floods_as_a_share_of_gdp',
 'economic_damages_from_storms',
 'economic_damages_from_storms_as_a_share_of_gdp',
 'economic_damages_from_wildfires',
 'economic_damages',
 'economic_damages_thousands',
 'drought_count',
 'extreme_temperatures_count',
 'floods_count',
 'storms_count',
 'wildfires_count',
 'population_population_growth_annual_percentage',
 'agriculture_value_added_constants',
 'agriculture_value_added_percentage_gdp'], axis=1)
temp_anom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 530 to 562
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   country_name                            33 non-null     object
#  1   year                                    33 non-null     int64
#  2   annual_co2_emissions_tons               33 non-null     int64
#  3   economic_damages_as_a_share_of_gdp      33 non-null     float64
#  4   people_affected_per_100k                33 non-null     float64
#  5   number_of_deaths                        33 non-null     float64
#  6   total_count_disasters                   33 non-null     float64
#  7   population_population_total             33 non-null     int64
#  8   temperature_change_temp_change_celsius  33 non-null     float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 2.6+ KB

# %%
temp_anom_df = temp_anom_df.dropna( )

# %%
temp_anom_df.head()
# Out:
#     country_name  year  annual_co2_emissions_tons  \
# 530        China  1988                 2425893553
# 531        China  1989                 2463654367
# 532        China  1990                 2484854820
# 533        China  1991                 2606096182
# 534        China  1992                 2730787587
#
#      economic_damages_as_a_share_of_gdp  people_affected_per_100k  \
# 530                            0.232596               6566.706679
# 531                            0.264113              11913.425736
# 532                            0.199686               4052.324298
# 533                            0.571885              17967.949093
# 534                            0.107345               2352.285018
#
#      number_of_deaths  total_count_disasters  population_population_total  \
# 530            2978.0                   13.0                   1101630000
# 531            3115.0                    8.0                   1118650000
# ...

# %%
temp_anom_df.set_index('year',inplace = True)
temp_anom_df.head()
# Out:
#      country_name  annual_co2_emissions_tons  \
# year
# 1988        China                 2425893553
# 1989        China                 2463654367
# 1990        China                 2484854820
# 1991        China                 2606096182
# 1992        China                 2730787587
#
#       economic_damages_as_a_share_of_gdp  people_affected_per_100k  \
# year
# 1988                            0.232596               6566.706679
# 1989                            0.264113              11913.425736
# 1990                            0.199686               4052.324298
# 1991                            0.571885              17967.949093
# 1992                            0.107345               2352.285018
#
#       number_of_deaths  total_count_disasters  population_population_total  \
# year
# 1988            2978.0                   13.0                   1101630000
# 1989            3115.0                    8.0                   1118650000
# ...

# %%
axis =temp_anom_df.plot.line(y='temperature_change_temp_change_celsius',rot=0)
print(axis)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
temp_anom_df= temp_anom_df.sort_values('temperature_change_temp_change_celsius',ascending=False)
temp_anom_df.head(10)
# Out:
#      country_name  annual_co2_emissions_tons  \
# year
# 2020        China                10667887453
# 2017        China                 9920459189
# 2007        China                 6978611952
# 2019        China                10489988555
# 2018        China                10289989525
# 2009        China                 7886532768
# 2016        China                 9720444086
# 2015        China                 9848419740
# 1998        China                 3360455433
# 1999        China                 3350340129
#
#       economic_damages_as_a_share_of_gdp  people_affected_per_100k  \
# year
# 2020                            0.039183              1.035393e+03
# 2017                            0.032390              1.025100e+03
# 2007                            0.053957              8.918435e+03
# 2019                            0.030014              3.515313e+02
# 2018                            0.027430              5.816630e+02
# ...

# %%
temp_anom_df.describe()
# Out:
#        annual_co2_emissions_tons  economic_damages_as_a_share_of_gdp  \
# count               3.300000e+01                           33.000000
# mean                6.058611e+09                            0.194432
# std                 3.099619e+09                            0.236345
# min                 2.425894e+09                            0.027430
# 25%                 3.357909e+09                            0.053346
# 50%                 5.223755e+09                            0.104668
# 75%                 9.720444e+09                            0.232596
# max                 1.066789e+10                            1.038466
#
#        people_affected_per_100k  number_of_deaths  total_count_disasters  \
# count              3.300000e+01         33.000000              33.000000
# mean               7.049445e+05       1500.303030              17.787879
# std                3.672169e+06       1222.328196               6.748878
# ...

# %%
import seaborn as sb

# Extract feature we're interested in
data = temp_anom_df['temperature_change_temp_change_celsius']

# Generate histogram/distribution plot
sb.displot(data, stat="density")

plt.show()

# %%
data.head()
# Out:
# year
# 2020    1.636
# 2017    1.566
# 2007    1.511
# 2019    1.413
# 2018    1.350
# Name: temperature_change_temp_change_celsius, dtype: float64

# %%
sb.displot(data, discrete = True, kde = True)
plt.show()

# %%
# Histogram
# ==============================================================================
import statsmodels.api as sm
from scipy import stats

# Valores de la media (mu) y desviación típica (sigma) de los datos
mu, sigma = stats.norm.fit(data)

# Valores teóricos de la normal en el rango observado
x_hat = np.linspace(min(data), max(data), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(x_hat, y_hat, linewidth=2, label='normal')
ax.hist(x=data, density=True, bins=30, color="#3182bd", alpha=0.5)
ax.plot(data, np.full_like(data, -0.01), '|k', markeredgewidth=1)
ax.set_title('BAHAMAS Anomalies in Temperature Distribution')
ax.set_xlabel('BAHAMAS Anomalies in Temperature')
ax.set_ylabel('Probability Density')
ax.legend();

# %%
# Gráfico Q-Q
# ==============================================================================
fig, ax = plt.subplots(figsize=(7,4))
sm.qqplot(
    data,
    fit   = True,
    line  = 'q',
    alpha = 0.4,
    lw    = 2,
    ax    = ax
)
ax.set_title('Temperature Q-Q Plot', fontsize = 15,
             fontweight = "bold")
ax.tick_params(labelsize = 7)

# %%
print('Kursotis:', stats.kurtosis(data))
print('Skewness:', stats.skew(data))
# Out:
# Kursotis: -0.8292280656319244
# Skewness: -0.2761369220041761

# %%
# Shapiro-Wilk test
# ==============================================================================
shapiro_test = stats.shapiro(data)
shapiro_test
# Out:
# ShapiroResult(statistic=0.9709911346435547, pvalue=0.5080611109733582)

# %%
# D'Agostino's K-squared test
# ==============================================================================
k2, p_value = stats.normaltest(data)
print(f"Estadístico = {k2}, p-value = {p_value}")
# Out:
# Estadístico = 1.3422512841753913, p-value = 0.5111329011384682
